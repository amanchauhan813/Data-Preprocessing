# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['class_label','alcohol','malic_acid']

# %%
df
# Out:
#      class_label  alcohol  malic_acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
plt.title('Before MinMax Scaler')
sns.kdeplot(df.alcohol)
sns.kdeplot(df.malic_acid)
# Out:
# <Axes: title={'center': 'Before MinMax Scaler'}, xlabel='alcohol', ylabel='Density'>

# %%
df.iloc[:,0:1]
# Out:
#      class_label
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 173            3
# 174            3
# 175            3
# 176            3
# 177            3
#
# [178 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,1:3],df.iloc[:,0:1],test_size=.3,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()
minmax.fit(x_train)
minmax_scaled_x_train=minmax.transform(x_train)
minmax_scaled_x_test=minmax.transform(x_test)

# %%
x_train_scaled=pd.DataFrame(minmax_scaled_x_train,columns=x_train.columns)
x_test_scaled=pd.DataFrame(minmax_scaled_x_test,columns=x_test.columns)

# %%
plt.title('After MinMax Scaler')
sns.kdeplot(x_train_scaled.alcohol)
sns.kdeplot(x_train_scaled.malic_acid)
# Out:
# <Axes: title={'center': 'After MinMax Scaler'}, xlabel='alcohol', ylabel='Density'>

# %%
sns.scatterplot(x_train.alcohol)
sns.scatterplot(x_train.malic_acid)
# Out:
# <Axes: ylabel='alcohol'>

# %%
sns.scatterplot(x_train_scaled.alcohol)
sns.scatterplot(x_train_scaled.malic_acid)
# Out:
# <Axes: ylabel='alcohol'>
